# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_cleaned_df = pd.read_csv("./submission/train_cleaned.csv")
train_cleaned_df.head(1)
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley ord_Lot Shape  \
# 0           60        RL     85.505051     13517   Pave   N_A           IR1
#
#   Land Contour ord_Utilities Lot Config  ... Screen Porch Pool Area  \
# 0          Lvl        AllPub    CulDSac  ...            0         0
#
#   ord_Pool QC ord_Fence Misc Feature Misc Val  Mo Sold  Yr Sold  Sale Type  \
# 0         N_A       N_A          N_A        0        3     2010        WD
#
#    SalePrice
# 0     130500
#
# [1 rows x 79 columns]

# %%
column_null_counts = train_cleaned_df.isnull().sum() *100/ len(train_cleaned_df) #Filter to find missing data in percetage 
missing_data_columns =column_null_counts[column_null_counts >0] # get only columns where missing data  >0
missing_data_columns.sort_values(ascending=False) # display them in highest missing data at top
# Out:
# Series([], dtype: float64)

# %%
### Creating a bunch of features better understand - Ames housing landscape

# %% [markdown]
# #  Neighborhood and home prices?

# %% [markdown]
# ###  What to expect as  a buyer in a average home in Ames Iowa

# %%
print (f"An Average home in Ames Iowa is priced at ${np.round(train_cleaned_df['SalePrice'].mean())}")


np.round(train_cleaned_df['Lot Area'].mean()), \
np.round(train_cleaned_df['feature_tot_squ_feet'].mean()),\

np.round(train_cleaned_df['TotRms AbvGrd'].median()), \
np.round(train_cleaned_df['Kitchen AbvGr'].median()),\
np.round(train_cleaned_df['Full Bath'].median()),\
np.round(train_cleaned_df['Half Bath'].median()),\
np.round(train_cleaned_df['Garage Cars'].median()),\
np.round(train_cleaned_df['Fireplaces'].median()),\
np.round(train_cleaned_df['f_tot_porches'].median()),\
'pools:',np.round(train_cleaned_df['f_has_pool'].median()),\
# Out:
# An Average home in Ames Iowa is priced at $181389.0
# (6.0, 1.0, 2.0, 0.0, 2.0, 1.0, 0.0, 'pools:', 0.0)

# %% [markdown]
# ### High priced  houses in , Stone Brook ,Northridge Heights,Northridge,Timber,GrnHill than average

# %%
train_cleaned_df['Neighborhood'].value_counts().head(30).plot(kind='barh', figsize=(20,10),sort_columns=False)
plt.xlabel('Number of homes' ,fontsize=20)
plt.ylabel('Neighborhood' ,fontsize=20)
plt.title(" Home distribution in Ames Iowa", fontsize=30);

# %%
plt.figure(figsize=(40,10))
sns.set(style="whitegrid")
aff_c = 'blue'
low_cost_c ='orange'
my_pal = {'Sawyer' :'g', 'SawyerW' :'g', 'NAmes' :'g' , 'Timber' :aff_c , 'Edwards' :'g' , 
          'OldTown' :'g','BrDale' :'g', 'CollgCr' :'g', 'Somerst' :aff_c, 'Mitchel' :'g', 
          'StoneBr' :aff_c, 'NridgHt':aff_c,'Gilbert' :'g', 'Crawfor' :'g', 'IDOTRR' :'g', 
          'NWAmes' :'g', 'Veenker' :aff_c, 'MeadowV':'g','SWISU' :'g', 'NoRidge' :aff_c, 
          'ClearCr' :'g', 'Blmngtn' :'g', 'BrkSide' :'g', 'NPkVill':'g',
          'Blueste' :'g', 'GrnHill' :aff_c, 'Greens' :'g', 'Landmrk' :'g'} 

b= sns.boxplot(
    data=train_cleaned_df,
    x='Neighborhood',
    y='SalePrice',
    color='green', palette =my_pal);

b.axes.set_title("Home sale price distribution by neighborhood",fontsize=50)
b.set_xlabel("Neighborhoods",fontsize=30)
b.set_ylabel("SalePrice in $",fontsize=20)
b.tick_params(labelsize=20)
b.axes.axhline(188000,ls='-', color ="blue",linewidth=4);

# %%
train_cleaned_df[train_cleaned_df['Neighborhood'] =='IDOTRR']
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 28            190   C (all)     75.000000      8250   Pave   N_A
# 75             30        RM     54.857143      6291   Grvl   N_A
# 79             50        RM     50.000000      7288   Pave   N_A
# 103            30   C (all)     72.000000      9392   Pave   N_A
# 129            80        RM     75.000000      6000   Pave   N_A
# ...           ...       ...           ...       ...    ...   ...
# 1939           50   C (all)     60.000000      7500   Pave   N_A
# 1990           50        RM     60.000000     10320   Pave  Grvl
# 2004           30   C (all)     69.000000     12366   Pave   N_A
# 2011           30        RM     58.000000      8154   Pave   N_A
# 2024           50   C (all)     66.000000      8712   Pave  Pave
#
#      ord_Lot Shape Land Contour ord_Utilities Lot Config  ...  \
# 28             Reg          Lvl        AllPub     Inside  ...
# 75             IR1          Lvl        AllPub     Inside  ...
# 79             Reg          Lvl        AllPub     Inside  ...
# 103            Reg          Lvl        AllPub     Corner  ...
# 129            Reg          Lvl        AllPub     Inside  ...
# ...            ...          ...           ...        ...  ...
# 1939           Reg          Lvl        AllPub     Inside  ...
# 1990           Reg          Lvl        AllPub     Inside  ...
# 2004           Reg          Lvl        AllPub     Inside  ...
# 2011           Reg          Lvl        AllPub     Inside  ...
# 2024           Reg          HLS        AllPub     Inside  ...
#
#      feature_tot_squ_feet f_has_pool f_has_wooden_deck f_has_enclosed_porch  \
# 28                 2948.0          0                 0                    1
# 75                 1536.0          0                 0                    1
# 79                 2537.0          0                 0                    0
# 103                1042.0          0                 0                    1
# 129                2280.0          0                 0                    0
# ...                   ...        ...               ...                  ...
# 1939               1826.0          0                 1                    1
# 1990               2026.0          0                 1                    0
# 2004                729.0          0                 0                    1
# 2011               1020.0          0                 0                    0
# 2024               2037.0          0                 1                    1
#
#      f_has_open_porch f_has_screen_porch  f_has_3Ssn_porch  f_tot_porches  \
# 28                  0                  0                 0              1
# 75                  0                  0                 0              1
# 79                  0                  0                 1              0
# 103                 1                  0                 0              1
# 129                 1                  1                 0              0
# ...               ...                ...               ...            ...
# 1939                0                  0                 0              1
# 1990                0                  1                 0              0
# 2004                0                  0                 0              1
# 2011                0                  0                 0              0
# 2024                0                  0                 0              1
#
#       f_in_affluent_neighborhood  f_new_or_remodeled
# 28                             0                   1
# 75                             0                   0
# 79                             0                   1
# 103                            0                   0
# 129                            0                   0
# ...                          ...                 ...
# 1939                           0                   0
# 1990                           0                   0
# 2004                           0                   0
# 2011                           0                   0
# 2024                           0                   0
#
# [68 rows x 89 columns]

# %%
plt.figure(figsize=(6,8))
plt.scatter(train_cleaned_df['MS Zoning'],train_cleaned_df['Neighborhood'])
#plt.xticks('')
plt.legend()
  A	Agriculture
       C	Commercial
       FV	Floating Village Residential
       I	Industrial
       RH	Residential High Density
       RL	Residential Low Density
       RP	Residential Low Density Park 
       RM	Residential Medium Density
# Out:
# No handles with labels found to put in legend.

# %%
plt.scatter(train_cleaned_df['f_in_affluent_neighborhood'],train_cleaned_df['SalePrice'])
plt.title("The houses in affluent areas are may affect the sale price")
# Out:
# Text(0.5, 1.0, 'The houses in affluent areas are may affect the sale price')

# %% [markdown]
# ###   Homes with wood deck on average have 76% more than those dont.

# %%
plt.scatter(train_cleaned_df['Wood Deck SF'],train_cleaned_df['SalePrice']);
train_cleaned_df.groupby('f_has_wooden_deck').mean()['SalePrice']
np.round(15781300/207313)
# Out:
# 76.0

# %% [markdown]
# # Age of the house and home prices?

# %%
plt.scatter(train_cleaned_df['Year Built'],train_cleaned_df['SalePrice'],label ="newly built")
plt.scatter(train_cleaned_df['Year Remod/Add'],train_cleaned_df['SalePrice'],alpha =0.2,label ="re-model")
plt.legend()
plt.xlabel('Year')
plt.ylabel('Sale Price in USD')
plt.title ('Newer or remodeled houses increase house valuation')
# Out:
# Text(0.5, 1.0, 'Newer or remodeled houses increase house valuation')

# %%
plt.plot(train_cleaned_df['Yr Sold'].value_counts().sort_index(),label ='Year sold')
plt.plot(train_cleaned_df['Year Built'].value_counts().sort_index(),label ='Year built')
plt.plot(train_cleaned_df['Year Remod/Add'].value_counts().sort_index(),label ='Year remodeled')
plt.xlabel('Year')
plt.xlabel('houses sold')
plt.legend()
plt.title("Age of the houses")
# Out:
# Text(0.5, 1.0, 'Age of the houses')

# %%
plt.scatter (train_cleaned_df['f_new_or_remodeled'],train_cleaned_df["SalePrice"])

# %% [markdown]
# #  Zoning and home prices ?

# %%
#Looking at the relation between zoining and  home prices I would have expected that home prices
#in commeritial will be higher than residential

# %%
train_cleaned_df['MS Zoning'].value_counts().head(30).plot(kind='barh', figsize=(20,10),sort_columns=False)
plt.xlabel('Number of homes' ,fontsize=20)
plt.ylabel('Neighborhood' ,fontsize=20)
plt.title(" Home distribution in Ames Iowa", fontsize=30);

# %%
plt.figure(figsize=(40,10))
sns.set(style="whitegrid")
aff_c = 'blue'
low_cost_c ='orange'
my_pal = {'C (all)' :'g', 'FV' :'g', 'RH' :'g' , 'RV' :aff_c , 'RL' :'g' , 
          'I (all)' :'g','RP' :'g', 'RM' :'g','A (agr)':'g'} 

b= sns.boxplot(
    data=train_cleaned_df,
    x='MS Zoning',
    y='SalePrice',
    color='green', palette =my_pal);

b.axes.set_title("Home sale price distribution by zoing",fontsize=50)
b.set_xlabel("Neighborhoods",fontsize=30)
b.set_ylabel("SalePrice in $",fontsize=20)
b.tick_params(labelsize=20)
b.axes.axhline(188000,ls='-', color ="blue",linewidth=4);

# %%
plt.figure(figsize=(6,8))
plt.scatter(train_cleaned_df['MS Zoning'],train_cleaned_df['Neighborhood'])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(40,10))
sns.set(style="whitegrid")
aff_c = 'blue'
low_cost_c ='orange'
my_pal = {'C (all)' :'g', 'FV' :'g', 'RH' :'g' , 'RV' :aff_c , 'RL' :'g' , 
          'I (all)' :'g','RP' :'g', 'RM' :'g','A (agr)':'g'} 

b= sns.boxplot(
    data=train_cleaned_df,
    x='Exterior 2nd',
    y='SalePrice',
    color='green');

b.axes.set_title("Home sale price distribution by zoing",fontsize=50)
b.set_xlabel("Exterior 2",fontsize=30)
b.set_ylabel("SalePrice in $",fontsize=20)
b.tick_params(labelsize=20)
b.axes.axhline(188000,ls='-', color ="blue",linewidth=4);

# %%
train_df.to_csv("./submission/train_cleaned.csv",index=False)
test_df.to_csv("./submission/test_cleaned.csv",index=False)

# %% [markdown]
# ### References`
# https://www.drawingfromdata.com/setting-figure-size-using-seaborn-and-matplotlib
# https://www.windermere.com/blogs/windermere/posts/how-neighborhood-affects-home-value
